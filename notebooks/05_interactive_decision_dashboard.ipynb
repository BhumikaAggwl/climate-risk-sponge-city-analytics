# %%
import pandas as pd

df = pd.read_csv(
    "../data/processed/scri_dataset.csv"
)

df.head()
# Out:
#     lat    lon  mean_annual_rf  std_annual        cv    dry_days  heavy_days  \
# 0  8.25  77.00      1368.70980   409.68338  0.299321  253.051282    0.487179
# 1  8.25  77.25      1163.10000   317.94876  0.273363  265.871795    0.487179
# 2  8.25  77.50       749.88873   343.41086  0.457949  313.076923    0.282051
# 3  8.25  77.75       758.49920   328.97153  0.433714  294.102564    0.256410
# 4  8.50  76.75      1833.17690   363.57733  0.198332  233.205128    0.820513
#
#     rf_norm   cv_norm  dry_norm  heavy_norm      scri risk_tier    scri_z
# 0  0.142809  0.971563  0.544681    0.982680  0.640340      High  0.706958
# 1  0.120985  0.975863  0.481214    0.982680  0.622174      High  0.389884
# 2  0.077127  0.945286  0.247525    0.989973  0.556458  Moderate -0.757169
# 3  0.078041  0.949300  0.341457    0.990884  0.576750  Moderate -0.402976
# 4  0.192108  0.988292  0.642930    0.970830  0.675999  Critical  1.329369

# %%
df.to_csv(
    "../dashboard/scri_dashboard_data.csv",
    index=False
)
